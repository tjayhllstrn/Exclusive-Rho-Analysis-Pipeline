# %%
import sys
import os
from importlib import import_module
sys.path.append('/w/hallb-scshelf2102/clas12/users/tjhellst/clas-ana-scaffold-tyler/src') 
from AsymmetryUtils import *
import numpy as np

# %%
inputFiles = ["out/pippi0_spring2019_in_pass2/pippi0_spring2019_in_pass2.root","out/pippi0_fall2018_in_pass2/pippi0_fall2018_in_pass2.root"]
outputDir = "./out/test"#"./out/BSA_Plots/pippi0_RGA_inbending_pass2_merged"
filename = "MLM_zbinning"
fit_type = "MLM"    #this can be "MLM" "chi2" or "MLMchi2
obs = "z"
bin_edges = [0.93, 0.96]#[0.66, 0.74, 0.79, 0.82, 0.85, 0.88, 0.91, 0.93, 0.96, 1]
graph_title = "RGA #pi^{+}#pi^{0} inbending Merged"
plot_type = "sideband_comp"  #this can be "sideband_comp" "sig_only", "MLMchi2_comp", or "MLMchi2_sideband_comp"
save_purity_plot = True
treeName = "pippi0"
exclusiveFit = "Mx"

# %%
#ROOT.gROOT.SetBatch(True)
    
if not isinstance(inputFiles, list):
    inputFiles = [inputFiles] 

if not os.path.isdir(outputDir):
    print(f"The directory '{outputDir}' does not exist.")
    sys.exit(1)

if exclusiveFit == "Mh":
    sigbkg_ub = 0.9
    sigbkg_lb = 0.65
    bkg_ub = 1.7
    bkg_lb = 1.1
elif exclusiveFit == "Mx": #when fitting with Mx as main independed var
    sigbkg_ub = 1.15
    sigbkg_lb = 0.85
    bkg_ub = 2.75
    bkg_lb = 1.4

# %% [markdown]
# ## MLM Method

# %%
A_sig_results = []
print("\033[92mfitting sig + bkg region\033[0m")
A_sigbkg_results,bin_centers = RunFittingMLM(obs,bin_edges,
                                             inputFiles,treeName,
                                             sigbkg_lb,sigbkg_ub,
                                             exclusiveFit,"sim") #runs "sim" or "single"
print("\033[92mfitting bkg region\033[0m")
A_bkg_results,bin_centers = RunFittingMLM(obs,bin_edges,
                                          inputFiles,treeName,
                                          bkg_lb,bkg_ub,
                                          exclusiveFit,"sim")
# Out:
# fitting sig + bkg region
# ---------------------------------------------------------------------------------
# fitting bin 0.930<z<0.960:  1 of 1
# fitting bkg region
# ---------------------------------------------------------------------------------
# fitting bin 0.930<z<0.960:  1 of 1
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(hel) TTree Int_t branch hel will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping event #2 because z cannot accommodate the value 0.84307
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping event #3 because z cannot accommodate the value 0.84307
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping event #4 because z cannot accommodate the value 0.875613
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping event #5 because z cannot accommodate the value 0.875613
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(posData) Ignored 498988 out-of-range events
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(hel) TTree Int_t branch hel will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping event #2 because z cannot accommodate the value 0.84307
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping event #3 because z cannot accommodate the value 0.84307
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping event #4 because z cannot accommodate the value 0.875613
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping event #5 because z cannot accommodate the value 0.875613
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(negData) Ignored 498988 out-of-range events
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(simPdf) fixing normalization set for coefficient determination to observables in data
# [#0] ERROR:InputArguments -- The pdf "_neg_NegProbFxn" of type RooGenericPdf did not overload RooAbsPdf::createExpectedEventsFunc()!
# [#0] ERROR:InputArguments -- The pdf "_pos_PosProbFxn" of type RooGenericPdf did not overload RooAbsPdf::createExpectedEventsFunc()!
# [#1] INFO:Fitting -- using CPU computation library compiled with -mavx2
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_simPdf_combData) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(_pos_PosProbFxn_Int[_pos_eps,_pos_phi]) using numeric integrator RooAdaptiveIntegratorND to calculate Int(_pos_eps,_pos_phi)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(_neg_NegProbFxn_Int[_neg_eps,_neg_phi]) using numeric integrator RooAdaptiveIntegratorND to calculate Int(_neg_eps,_neg_phi)
# [#1] INFO:Minimization -- Command timer: Real time 0:00:00, CP time 0.120
# [#1] INFO:Minimization -- Session timer: Real time 0:00:00, CP time 0.120
# [#1] INFO:Minimization -- Command timer: Real time 0:00:00, CP time 0.020
# [#1] INFO:Minimization -- Session timer: Real time 0:00:00, CP time 0.140, 2 slices
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(hel) TTree Int_t branch hel will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping event #0 because z cannot accommodate the value 0.451548
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping event #1 because z cannot accommodate the value 0.451548
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping event #2 because z cannot accommodate the value 0.526848
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping event #3 because z cannot accommodate the value 0.48554
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(posData) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(posData) Ignored 5048138 out-of-range events
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(hel) TTree Int_t branch hel will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping event #0 because z cannot accommodate the value 0.451548
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping event #1 because z cannot accommodate the value 0.451548
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping event #2 because z cannot accommodate the value 0.526848
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping event #3 because z cannot accommodate the value 0.48554
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(negData) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(negData) Ignored 5048138 out-of-range events
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(simPdf) fixing normalization set for coefficient determination to observables in data
# [#0] ERROR:InputArguments -- The pdf "_neg_NegProbFxn" of type RooGenericPdf did not overload RooAbsPdf::createExpectedEventsFunc()!
# [#0] ERROR:InputArguments -- The pdf "_pos_PosProbFxn" of type RooGenericPdf did not overload RooAbsPdf::createExpectedEventsFunc()!
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_simPdf_combData) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(_pos_PosProbFxn_Int[_pos_eps,_pos_phi]) using numeric integrator RooAdaptiveIntegratorND to calculate Int(_pos_eps,_pos_phi)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(_neg_NegProbFxn_Int[_neg_eps,_neg_phi]) using numeric integrator RooAdaptiveIntegratorND to calculate Int(_neg_eps,_neg_phi)
# [#1] INFO:Minimization -- Command timer: Real time 0:00:00, CP time 0.000
# [#1] INFO:Minimization -- Session timer: Real time 0:00:00, CP time 0.000
# [#1] INFO:Minimization -- Command timer: Real time 0:00:00, CP time 0.000
# [#1] INFO:Minimization -- Session timer: Real time 0:00:00, CP time 0.000, 2 slices
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# IOStream.flush timed out
# Error in <TBufferFile::WriteByteCount>: bytecount too large (more than 1073741822)
# Error in <TBufferFile::WriteByteCount>: bytecount too large (more than 1073741822)
# Error in <TBufferFile::CheckByteCount>: object of class TObjArray read too many bytes: 1177639707 instead of 103897883
# Warning in <TBufferFile::CheckByteCount>: TObjArray::Streamer() not in sync with data, fix Streamer()
# Error in <TBufferFile::CheckByteCount>: Byte count probably corrupted around buffer position 103898200:
# 	-1428340775 for a possible maximum of 1272226720
# Error in <TBufferFile::CheckByteCount>: object of class TTree read too many bytes: 1376124928 instead of 103898255
# Warning in <TBufferFile::CheckByteCount>: TTree::Streamer() not in sync with data, fix Streamer()
# Error in <TBufferFile::WriteByteCount>: bytecount too large (more than 1073741822)
# Error in <TBufferFile::WriteByteCount>: bytecount too large (more than 1073741822)
# Error in <TBufferFile::CheckByteCount>: object of class TObjArray read too many bytes: 1177639707 instead of 103897883
# Warning in <TBufferFile::CheckByteCount>: TObjArray::Streamer() not in sync with data, fix Streamer()
# Error in <TBufferFile::CheckByteCount>: Byte count probably corrupted around buffer position 103898200:
# 	-1428340775 for a possible maximum of 1272226720
# Error in <TBufferFile::CheckByteCount>: object of class TTree read too many bytes: 1376124928 instead of 103898255
# Warning in <TBufferFile::CheckByteCount>: TTree::Streamer() not in sync with data, fix Streamer()
# IOStream.flush timed out
# Warning in <ROOT::Math::Fitter::CalculateHessErrors>: Error when calculating Hessian

# %%
#calculate purity by bin
u_results = []
if exclusiveFit == "Mh":
    for idx in range(len(bin_edges)-1):
        obsmin = bin_edges[idx]
        obsmax = bin_edges[idx+1]
        u_results.append(purityCalc(inputFiles,outputDir,filename,sigbkg_lb,sigbkg_ub,obs,obsmin,obsmax,treeName,save_purity_plot))
elif exclusiveFit == "Mx":
    for idx in range(len(bin_edges)-1):
        obsmin = bin_edges[idx]
        obsmax = bin_edges[idx+1]
        u_results.append(purityCalc_mxFit(inputFiles,outputDir,filename,sigbkg_lb,sigbkg_ub,obs,obsmin,obsmax,treeName,save_purity_plot))
# Out:
# chain Entries = 40941520
# u = 0.8813111391751832+/-0.07438644176808334
# [#1] INFO:Eval -- RooRealVar::setRange(Mx) new range named 'fullRange' created with bounds [0.5,2]
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roo_DS) Skipping event #0 because Mh cannot accommodate the value 1.42403
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roo_DS) Skipping event #1 because Mh cannot accommodate the value 1.42403
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roo_DS) Skipping event #2 because Mdiphoton cannot accommodate the value 0.379073
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roo_DS) Skipping event #3 because Mdiphoton cannot accommodate the value 0.379073
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roo_DS) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(roo_DS) Ignored 40813318 out-of-range events
# [#1] INFO:Eval -- RooRealVar::setRange(Mx) new range named 'fit_nll_model_ext_roo_DS' created with bounds [0.5,2]
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_ext) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_model_ext_roo_DS) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0633044	N_{bkg}=35321.7	N_{sig}=97257.7	m_{0}=0.989694	p1=0.790885	p2=1	p3=-0.926694	p4=-0.922126
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.097e-55,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 97257.7,N_{bkg} = 35321.7)
#     ... (remaining 2038 messages suppressed)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.922126/2.18443, denominator=background_Int[Mx]=2.18443
#     ... (remaining 2038 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0626391	N_{bkg}=31824.2	N_{sig}=112415	m_{0}=0.990134	p1=0.955081	p2=0.999999	p3=-0.995369	p4=-0.928637
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.31051e-56,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 112415,N_{bkg} = 31824.2)
#     ... (remaining 2038 messages suppressed)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.928637/2.18573, denominator=background_Int[Mx]=2.18573
#     ... (remaining 2038 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0642975	N_{bkg}=40909.4	N_{sig}=76574.1	m_{0}=0.989017	p1=0.366958	p2=1	p3=-0.683114	p4=-0.911849
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.28103e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 76574.1,N_{bkg} = 40909.4)
#     ... (remaining 62 messages suppressed)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911849/2.18237, denominator=background_Int[Mx]=2.18237
#     ... (remaining 62 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0643305	N_{bkg}=41102.7	N_{sig}=75927.1	m_{0}=0.988994	p1=0.350264	p2=1	p3=-0.67249	p4=-0.911496
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.44533e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75927.1,N_{bkg} = 41102.7)
#     ... (remaining 38 messages suppressed)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911496/2.1823, denominator=background_Int[Mx]=2.1823
#     ... (remaining 38 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0643635	N_{bkg}=41296.5	N_{sig}=75282.8	m_{0}=0.988971	p1=0.333458	p2=1	p3=-0.661726	p4=-0.911142
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.63035e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 75282.8,N_{bkg} = 41296.5)
#     ... (remaining 24 messages suppressed)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.911142/2.18223, denominator=background_Int[Mx]=2.18223
#     ... (remaining 24 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0645448	N_{bkg}=42370.3	N_{sig}=71788.3	m_{0}=0.988844	p1=0.239264	p2=1	p3=-0.600114	p4=-0.909185
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.15028e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 71788.3,N_{bkg} = 42370.3)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.15028e-53,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 71788.3,N_{bkg} = 42370.3)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.909184/2.18184, denominator=background_Int[Mx]=2.18184
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.909184/2.18184, denominator=background_Int[Mx]=2.18184
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.078026	N_{bkg}=53062.1	N_{sig}=128678	m_{0}=0.9924	p1=0.997074	p2=1	p3=-0.992405	p4=-0.983019
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 3.1385e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 128678,N_{bkg} = 53062.1)
#     ... (remaining 2038 messages suppressed)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.983019/2.1966, denominator=background_Int[Mx]=2.1966
#     ... (remaining 2038 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0817713	N_{bkg}=61408.5	N_{sig}=119164	m_{0}=0.993369	p1=0.939406	p2=1	p3=-0.958525	p4=-0.998478
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 6.03898e-33,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 119164,N_{bkg} = 61408.5)
#     ... (remaining 2038 messages suppressed)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998478/2.1997, denominator=background_Int[Mx]=2.1997
#     ... (remaining 2038 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0663201	N_{bkg}=44720.7	N_{sig}=73060	m_{0}=0.989166	p1=0.265355	p2=1	p3=-0.608145	p4=-0.921887
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.15638e-50,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 73060,N_{bkg} = 44720.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 2.15638e-50,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 73060,N_{bkg} = 44720.7)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.921887/2.18438, denominator=background_Int[Mx]=2.18438
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.921887/2.18438, denominator=background_Int[Mx]=2.18438
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0785188	N_{bkg}=58582.9	N_{sig}=108227	m_{0}=0.99208	p1=0.674911	p2=1	p3=-0.648845	p4=-0.997101
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 8.4027e-36,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 108227,N_{bkg} = 58582.9)
#     ... (remaining 202 messages suppressed)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.9971/2.19942, denominator=background_Int[Mx]=2.19942
#     ... (remaining 202 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0661693	N_{bkg}=44637.1	N_{sig}=72722.9	m_{0}=0.9891	p1=0.244448	p2=1	p3=-0.586318	p4=-0.922731
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.25253e-50,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 72722.9,N_{bkg} = 44637.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.25253e-50,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 72722.9,N_{bkg} = 44637.1)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.92273/2.18455, denominator=background_Int[Mx]=2.18455
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.92273/2.18455, denominator=background_Int[Mx]=2.18455
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0798829	N_{bkg}=75267.7	N_{sig}=113107	m_{0}=0.991924	p1=0.840784	p2=1	p3=-0.604735	p4=-0.998059
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(Mx = 2), !pdfs=(sig_over_sig_Int[Mx] = 1.31169e-34,background_over_background_Int[Mx] = nan), !coefficients=(N_{sig} = 113107,N_{bkg} = 75267.7)
#     ... (remaining 342 messages suppressed)
# RooAbsPdf::background_over_background_Int[Mx][ numerator=background denominator=background_Int[Mx] ]
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#      p.d.f value is less than zero, trying to recover @ numerator=background=-0.998059/2.19961, denominator=background_Int[Mx]=2.19961
#     ... (remaining 342 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03667e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#sigma_{R}=0.0662816	N_{bkg}=45355.3	N_{sig}=73001.1	m_{0}=0.989099	p1=0.258123	p2=1	p3=-0.584183	p4=-0.922918
# RooAddPdf::model_ext[ N_{sig} * sig_over_sig_Int[Mx] + N_{bkg} * background_over_background_Int[Mx] ]
# ...
#      p.d.f value is less than zero (-1.056341), trying to recover @ x=Mx=1.91, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.925 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.049650), trying to recover @ x=Mx=1.925, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.94 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.040974), trying to recover @ x=Mx=1.94, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.955 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.030310), trying to recover @ x=Mx=1.955, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.97 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.017659), trying to recover @ x=Mx=1.97, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.985 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.003021), trying to recover @ x=Mx=1.985, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=2 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.986400), trying to recover @ x=Mx=2, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.3325 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.031396), trying to recover @ x=Mx=1.3325, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.3475 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.079831), trying to recover @ x=Mx=1.3475, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.3625 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.127815), trying to recover @ x=Mx=1.3625, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.3775 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.175272), trying to recover @ x=Mx=1.3775, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.3925 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.222129), trying to recover @ x=Mx=1.3925, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.4075 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.268315), trying to recover @ x=Mx=1.4075, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.4225 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.313760), trying to recover @ x=Mx=1.4225, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.4375 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.358395), trying to recover @ x=Mx=1.4375, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.4525 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.402156), trying to recover @ x=Mx=1.4525, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.4675 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.444978), trying to recover @ x=Mx=1.4675, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.4825 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.486800), trying to recover @ x=Mx=1.4825, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.4975 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.527560), trying to recover @ x=Mx=1.4975, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.5125 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.567201), trying to recover @ x=Mx=1.5125, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.5275 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.605666), trying to recover @ x=Mx=1.5275, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.5425 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.642900), trying to recover @ x=Mx=1.5425, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.5575 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.678852), trying to recover @ x=Mx=1.5575, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.5725 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.713470), trying to recover @ x=Mx=1.5725, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.5875 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.746706), trying to recover @ x=Mx=1.5875, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.6025 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.778512), trying to recover @ x=Mx=1.6025, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.6175 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.808844), trying to recover @ x=Mx=1.6175, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.6325 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.837658), trying to recover @ x=Mx=1.6325, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.6475 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.864914), trying to recover @ x=Mx=1.6475, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.6625 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.890571), trying to recover @ x=Mx=1.6625, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.6775 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.914592), trying to recover @ x=Mx=1.6775, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.6925 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.936942), trying to recover @ x=Mx=1.6925, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.7075 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.957587), trying to recover @ x=Mx=1.7075, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.7225 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.976496), trying to recover @ x=Mx=1.7225, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.7375 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.993638), trying to recover @ x=Mx=1.7375, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.7525 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.008985), trying to recover @ x=Mx=1.7525, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.7675 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.022511), trying to recover @ x=Mx=1.7675, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.7825 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.034192), trying to recover @ x=Mx=1.7825, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.7975 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.044006), trying to recover @ x=Mx=1.7975, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.8125 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.051933), trying to recover @ x=Mx=1.8125, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.8275 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.057953), trying to recover @ x=Mx=1.8275, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.8425 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.062050), trying to recover @ x=Mx=1.8425, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.8575 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.064210), trying to recover @ x=Mx=1.8575, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.8725 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.064419), trying to recover @ x=Mx=1.8725, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.8875 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.062667), trying to recover @ x=Mx=1.8875, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.9025 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.058944), trying to recover @ x=Mx=1.9025, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.9175 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.053244), trying to recover @ x=Mx=1.9175, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.9325 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.045560), trying to recover @ x=Mx=1.9325, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.9475 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.035891), trying to recover @ x=Mx=1.9475, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.9625 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.024233), trying to recover @ x=Mx=1.9625, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.9775 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-1.010588), trying to recover @ x=Mx=1.9775, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# [#0] WARNING:Plotting -- At observable [x]=1.9925 RooChebychev::background[ x=Mx coefList=(p1,p2,p3,p4) ]
#      p.d.f value is less than zero (-0.994958), trying to recover @ x=Mx=1.9925, coefList=(p1 = 0.999918 +/- 7.8283e-05,p2 = 1 +/- 8.34417e-06,p3 = -0.25373 +/- 0.00549006,p4 = -0.9864 +/- 1.21822e-07)
# Info in <TCanvas::Print>: png file ./out/test/PurityFits/MLM_zbinning_PurityFit_0.93-0.96.png has been created

# %%
#plot purity by bin:
u_vals = [entry[0] for entry in u_results]
u_errs = [entry[1] for entry in u_results]
#shift points to avoid overlapping error bars:
jittered_bin_centers = [entry*(1+0.005*idx) for entry in bin_centers]
x = np.array(jittered_bin_centers, dtype='float64')
y = np.array(u_vals, dtype='float64')
x_errs = np.zeros_like(x)
y_errs = np.array(u_errs,dtype='float64')
        
gr = ROOT.TGraphErrors(len(x),x,y,x_errs,y_errs)
gr.SetMarkerStyle(20)
gr.SetMarkerColor(ROOT.kBlue)
gr.SetLineColor(ROOT.kBlue)
gr.SetLineWidth(2)
gr.SetTitle("")
if obs =="cth":
    gr.GetXaxis().SetTitle(f"cos#theta")
else:
    gr.GetXaxis().SetTitle(f"{obs}")

leg = ROOT.TPaveText(0.15, 0.75, 0.55, 0.85, "NDC") #ROOT.TLegend(0.15,0.75,0.55,0.85) #xmin,ymin,xmax.ymax
#leg.SetBorderSize(1)
leg.AddText("Exclusive Signal Purity")#leg.AddEntry(gr,"Exclusive Signal Purity","p")
leg.SetTextSize(0.04)
        
PurityOutputFile = os.path.join(outputDir,f"PurityFits/{filename}_purityPerBin.png")
c = ROOT.TCanvas()
gr.Draw("AP")
leg.Draw("SAME")
c.SaveAs(PurityOutputFile)
# Out:
# Info in <TCanvas::Print>: png file ./out/BSA_Plots/pippi0_RGA_inbending_pass2_merged/PurityFits/MLMchi2_zbinning_purityPerBin.png has been created

# %%
#sideband subtraction
for i in range(len(A_sigbkg_results)):
    A_sigbkg_val = A_sigbkg_results[i][0]
    A_sigbkg_err = A_sigbkg_results[i][1]
    A_bkg_val = A_bkg_results[i][0]
    A_bkg_err = A_bkg_results[i][1]
    u_val = u_results[i][0]
    u_err = u_results[i][1]
            
    A_sig_val = 1/u_val*(A_sigbkg_val-(1-u_val)*A_bkg_val)
    #error propogation based on general formula
    a = 1/u_val*A_sigbkg_err
    b = (1-u_val)/u_val * A_bkg_err
    c = ROOT.TMath.Power(u_val,-2)*u_err*(A_bkg_val-A_sigbkg_val)
    A_sig_err = ROOT.TMath.Sqrt(ROOT.TMath.Power(a,2)+ROOT.TMath.Power(b,2)+ROOT.TMath.Power(c,2))
    
    A_sig_results.append((A_sig_val,A_sig_err))

# %% [markdown]
# ## Chi2 Method

# %%
phibn_edges = np.linspace(-3.14,3.14,7) #[-3.14,-2.38,-1.57, 0.0,1.57,2.38, 3.14]

# %%
ROOT.gSystem.Load("/w/hallb-scshelf2102/clas12/users/tjhellst/clas-ana-scaffold-tyler/macros/libPhiBinnedFitRunner.so")
runner = ROOT.PhiBinnedFitRunner()
alpha = runner.Run(bin_edges,phibn_edges,inputFiles,outputDir,obs,treeName)
results = list(alpha)
A_sig_results_chi2 = []
for i in range(0,len(results),2):
    A_sig_results_chi2.append((results[i],results[i+1]))

# %% [markdown]
# ## Plot Results

# %%
if plot_type == "sideband_comp":
    results = [A_sig_results,A_sigbkg_results,A_bkg_results]
    legend_names = [f"A_{{sig}} {fit_type} Fit",f"A_{{sig+bkg}} {fit_type} Fit",f"A_{{bkg}} {fit_type} Fit"]

if plot_type == "sig_only":
    results = [A_sig_results]
    legend_names = [f"A_{{sig}} {fit_type} Fit"]

if plot_type == "MLMchi2_comp":
    results = [A_sig_results_chi2,A_sig_results]
    legend_names = [f"A_{{sig}} MLM Fit",f"A_{{sig}} chi2 Fit"]
if plot_type == "MLMchi2_sideband_comp":
    results = [A_sig_results_chi2,A_sig_results,A_sigbkg_results,A_bkg_results]
    legend_names = [f"A_{{sig}} chi2 Fit",f"A_{{sig}} MLM Fit",f"A_{{sig+bkg}} {fit_type} Fit",f"A_{{bkg}} {fit_type} Fit"]
        
    
PlotGraphs(results,
            legend_names, graph_title,
            bin_centers,outputFile,obs)
