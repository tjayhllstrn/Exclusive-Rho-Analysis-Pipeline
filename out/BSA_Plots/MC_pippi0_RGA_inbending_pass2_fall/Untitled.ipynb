# %%
import ROOT

# %%
filename = "RESULTS_zbinning_1111.root"

# %%
file = ROOT.TFile(filename)
file.ls()
# Out:
# TFile**		RESULTS_zbinning_1111.root
#  TFile*		RESULTS_zbinning_1111.root
#   KEY: TGraphErrors	gr_0;1	MonteCarlo Fall Inbending
#   KEY: TGraphErrors	gr_1;1	Graph
#   KEY: TGraphErrors	gr_2;1	Graph
#   KEY: TGraphErrors	gr_3;1	Graph
#   KEY: TCanvas	c1;1	c1

# %%
c1 = file.Get("c1")
gr_0 = file.Get("gr_0")
gr_1 = file.Get("gr_1")
gr_2 = file.Get("gr_2")
gr_3 = file.Get("gr_3")
c1.Draw()

# %%
canvas = ROOT.TCanvas()
#gr_3.GetYaxis().SetRangeUser(0,0.05)
gr_3.Draw()
canvas.Draw()

# %%
zbin_edges = [0.66, 0.74, 0.79, 0.82, 0.85, 0.88, 0.91, 0.93, 0.96, 1]

# %%
canvas = ROOT.TCanvas()
for bn_idx in range(len(zbin_edges)-1):
    chain.Draw(f"Mh>>h_{bn_idx}(100,0.4,1.7)",Mdiphoton<0.16 && 0.115<Mdiphoton && 0.85<Mx && Mx < 1.05
