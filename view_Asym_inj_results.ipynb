# %%
import ROOT

# %% [markdown]
# This code is meant to add the asymmetry function plots to the corresponding results in out/

# %%
f_n = "out/pippi0_rgaMC_in_fa18_pass2_injAsym_A10/BSA_Plots/t_elec/MhMLM/cth_-1.00_1.000/AsymmetriesAsymmetries_per_t_elec.root"
f = ROOT.TFile(f_n)
f.ls()
# Out:
# TFile**		out/pippi0_rgaMC_in_fa18_pass2_injAsym_A10/BSA_Plots/t_elec/MhMLM/cth_-1.00_1.000/AsymmetriesAsymmetries_per_t_elec.root
#  TFile*		out/pippi0_rgaMC_in_fa18_pass2_injAsym_A10/BSA_Plots/t_elec/MhMLM/cth_-1.00_1.000/AsymmetriesAsymmetries_per_t_elec.root
#   KEY: TCanvas	Asymmetries_canvas;1	Asymmetries_canvas
#   KEY: TGraphErrors	A_sig_bkg;1	A_sig_bkg
#   KEY: TGraphErrors	A_bkg;1	A_bkg
#   KEY: TGraphErrors	A_sig;1	A_sig
#   KEY: TLegend	TPave;1	Legend of markers/lines/boxes to represent obj's
