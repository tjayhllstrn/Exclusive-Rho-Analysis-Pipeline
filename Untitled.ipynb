# %%
import ROOT

# %%
file1 = "out/MC_pippi0_in/45nA_job_3051_0.root"
file2 = "out/pippi0_fall2018_in_pass2/pippi0_fall2018_in_pass2.root"
file3 = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/clas12_dihadrons/projects/pipi0-paper-v5-pass2/data/piplus_pi0/Fall2018Spring2019_RGA_inbending_merged_exclusive_cuts.root"

# %%
chain1 = ROOT.TChain("pippi0")
chain1.Add(file1)
chain2 = ROOT.TChain("pippi0")
chain2.Add(file2)
chain3 = ROOT.TChain("dihadron_exclusive_cuts")
chain3.Add(file3)
# Out:
# 1

# %%
print(chain1.GetEntries())
print(chain2.GetEntries())
print(chain3.GetEntries())
# Out:
# 2372
# 19390864
# 2705411

# %%
file1_t = ROOT.TFile(file1)
file1_t.ls()
# Out:
# TFile**		out/MC_pippi0_in/45nA_job_3051_0.root
#  TFile*		out/MC_pippi0_in/45nA_job_3051_0.root
#   KEY: TTree	EventTree;21	EventTree [current cycle]
#   KEY: TTree	EventTree;20	EventTree [backup cycle]
#   KEY: TTree	EventTree;19	EventTree [backup cycle]
#   KEY: TTree	MLinput;4	Nearest neighbor information [current cycle]
#   KEY: TTree	MLinput;3	Nearest neighbor information [backup cycle]
#   KEY: TTree	pippi0;1	Tree

# %%
[b.GetName() for b in chain1.GetListOfBranches()]
# Out:
# ['hel',
#  'run',
#  'x',
#  'eps',
#  'gamma',
#  'x_true',
#  'Q2',
#  'Q2_true',
#  'z',
#  'pT',
#  'xF',
#  'xF1',
#  'xF2',
#  'phi',
#  'Mx',
#  'Mh',
#  'z_true',
#  'pT_true',
#  'xF_true',
#  'xF1_true',
#  'xF2_true',
#  'phi_true',
#  'Mx_true',
#  'Mh_true',
#  'Mdiphoton',
#  'Mdiphoton_true',
#  'th',
#  'th_true',
#  'cth',
#  'cth_true',
#  'MCtrue_containsNeutron',
#  'truepho1_pid',
#  'truepho2_pid',
#  'truepip_pid']

# %%
c1 = ROOT.TCanvas()
chain1.Draw("truepip_pid>>h(100,2100,2150)","","")
c1.Draw()

# %%
c = ROOT.TCanvas()
chain1.Draw("Mx>>h(150,0.5,3.5)","Mdiphoton<0.16 && 0.115<Mdiphoton&& 1.2<Mh&&Mh<1.6","goff")
chain1.Draw("Mx>>h1(150,0.5,3.5)","MCtrue_containsNeutron==1&&Mdiphoton<0.16 && 0.115<Mdiphoton&& 1.2<Mh&&Mh<1.6","goff")
h = ROOT.gDirectory.Get("h")
h.SetLineColor(ROOT.kRed)
h1 = ROOT.gDirectory.Get("h1")
leg = ROOT.TLegend(0.6,0.6,0.85,0.85)
leg.AddEntry(h,"Recon","l")
leg.AddEntry(h1,"MC","l")
h.SetStats(0)
h.Draw()
h1.Draw("SAME")
leg.Draw()
c.Draw()

# %%
chain1.Show(0)
# Out:
# ======> EVENT:0
#  A               = 0
#  evnum           = 12
#  uID             = 0
#  run             = -11
#  Pol             = 0.86
#  tPol            = 0
#  hwp             = 0
#  target          = -999
#  tSign           = 0
#  Nmax            = 9
#  x               = 0.137622
#  y               = 0.615752
#  W               = 3.38334
#  Q2              = 1.68626
#  nu              = 6.5295
#  truex           = 0.139782
#  truey           = 0.615607
#  trueQ2          = 1.71233
#  trueW           = 3.37906
#  truenu          = 6.52796
#  hel             = 0
#  truex           = 0.139782
#  truey           = 0.615607
#  trueW           = 3.37906
#  truenu          = 6.52796
#  pindex          = 0,
#                   1, 3, 4, 5, 6, 7, 8, 9
#  status          = -2221,
#                   2230, 4010, 2110, 2020, 2210, 2110, 2210, 2110
#  px              = -0.799315,
#                   -0.261056, 0.26892, -0.124987, -0.0529282, 0.138366,
#                   0.114417, 0.0970854, 0.0920234
#  py              = -0.0521215,
#                   -0.132631, 0.227793, -0.14127, 0.163152, -0.107213,
#                   -0.0877342, -0.0883249, -0.0798925
#  pz              = 3.99509,
#                   2.08531, 0.237476, 0.545427, 0.501121, 0.453553,
#                   0.350616, 0.349623, 0.30111
#  p               = 4.0746,
#                   2.10577, 0.424973, 0.577122, 0.529662, 0.486158,
#                   0.379105, 0.373448, 0.324836
#  E               = 4.0746,
#                   2.11039, 0.424973, 0.577122, 0.529662, 0.486158,
#                   0.379105, 0.373448, 0.324836
#  pid             = 11,
#                   211, 0, 22, 22, 22, 22, 22, 22
#  vx              = -0.0313624,
#                   -0.068878, -0.0170596, -0.0313624, -0.0313624, -0.0313624,
#                   -0.0313624, -0.0313624, -0.0313624
#  vy              = 0.581727,
#                   0.153442, 0.0201396, 0.581727, 0.581727, 0.581727,
#                   0.581727, 0.581727, 0.581727
#  vz              = -5.12154,
#                   -16.4828, -3.05394, -5.12154, -5.12154, -5.12154,
#                   -5.12154, -5.12154, -5.12154
#  chi2            = -0.473077,
#                   1.76055, 9999, 9999, 9999, 9999,
#                   9999, 9999, 9999
#  beta            = 1,
#                   0.9917, -99, 0.959696, 0.991023, 0.9372,
#                   0.937434, 0.98541, 0.928595
#  m               = 0.000510999,
#                   0.13957, 0, 0, 0, 0,
#                   0, 0, 0
#  theta           = 0.197875,
#                   0.139506, 0.977855, 0.332954, 0.329779, 0.368324,
#                   0.390146, 0.359128, 0.384568
#  eta             = 2.30999,
#                   2.66117, 0.63109, 1.7836, 1.79336, 1.68054,
#                   1.62158, 1.7064, 1.63635
#  phi             = -3.07648,
#                   -2.67152, 0.702789, -2.29512, 1.88449, -0.659218,
#                   -0.654161, -0.738184, -0.714952
#  truepx          = -0.8061,
#                   -999, -999, -999, -0.052, -999,
#                   -999, -999, -999
#  truepy          = -0.0435,
#                   -999, -999, -999, 0.1611, -999,
#                   -999, -999, -999
#  truepz          = 3.9954,
#                   -999, -999, -999, 0.4966, -999,
#                   -999, -999, -999
#  truep           = 4.07614,
#                   -999, -999, -999, 0.524661, -999,
#                   -999, -999, -999
#  truept          = 0.807273,
#                   -999, -999, -999, 0.169284, -999,
#                   -186.938, 0, 0, 226.066, 0,
#                   0, 0, 0
#  ecin_z          = 776.291,
#                   702.586, 0, 0, 705.36, 0,
#                   0, 0, 0
#  ecin_lu         = 31.4881,
#                   226.952, 0, 0, 221.283, 0,
#                   0, 0, 0
#  ecin_lv         = 395.97,
#                   338.366, 0, 0, 356.611, 0,
#                   0, 0, 0
#  ecin_lw         = 358.066,
#                   230.032, 0, 0, 223.976, 0,
#                   0, 0, 0
#  ecin_m2u        = -999,
#                   -999, -999, -999, -999, -999,
#                   -999, -999, -999
#  ecin_m2v        = -999,
#                   -999, -999, -999, -999, -999,
#                   -999, -999, -999
#  ecin_m2w        = -999,
#                   -999, -999, -999, -999, -999,
#                   -999, -999, -999
#  ecout_sector    = 0,
#                   5, 0, 0, 0, 0, 0, 0, 0
#  ecout_e         = 0,
#                   0.0465764, 0, 0, 0, 0,
#                   0, 0, 0
#  ecout_x         = 0,
#                   -157.05, 0, 0, 0, 0,
#                   0, 0, 0
#  ecout_y         = 0,
#                   -198.524, 0, 0, 0, 0,
#                   0, 0, 0
#  ecout_z         = 0,
#                   717.332, 0, 0, 0, 0,
#                   0, 0, 0
#  ecout_lu        = 0,
#                   241.275, 0, 0, 0, 0,
#                   0, 0, 0
#  ecout_lv        = 0,
#                   346.99, 0, 0, 0, 0,
#                   0, 0, 0
#  ecout_lw        = 0,
#                   243.035, 0, 0, 0, 0,
#                   0, 0, 0
#  ecout_m2u       = -999,
#                   -999, -999, -999, -999, -999,
#                   -999, -999, -999
#  ecout_m2v       = -999,
#                   -999, -999, -999, -999, -999,
#                   -999, -999, -999
#  ecout_m2w       = -999,
#                   -999, -999, -999, -999, -999,
#                   -999, -999, -999
#  sector          = 4,
#                   5, 0, 0, 0, 0, 0, 0, 0
#  traj_x1         = -48.3899,
#                   -25.6117, 0, 0, 0, 0,
#                   0, 0, 0
#  traj_y1         = 3.83787,
#                   -24.5403, 0, 0, 0, 0,
#                   0, 0, 0
#  traj_z1         = 236.814,
#                   243.497, 0, 0, 0, 0,
#                   0, 0, 0
#  traj_x2         = -70.6066,
#                   -42.9165, 0, 0, 0, 0,
#                   0, 0, 0
#  traj_y2         = 5.48309,
#                   -44.5583, 0, 0, 0, 0,
#                   0, 0, 0
#  traj_z2         = 367.789,
#                   372.713, 0, 0, 0, 0,
#                   0, 0, 0
#  traj_x3         = -77.7564,
#                   -92.1984, 0, 0, 0, 0,
#                   0, 0, 0
#  traj_y3         = 6.00584,
#                   -103.062, 0, 0, 0, 0,
#                   0, 0, 0
#  traj_z3         = 547.4,
#                   520.533, 0, 0, 0, 0,
#                   0, 0, 0
#  nphe_ltcc       = 0,
#                   0, 0, 0, 0, 0,
#                   0, 0, 0
#  nphe_htcc       = 7,
#                   0, 0, 0, 0, 0,
#                   0, 0, 0
#  p_gamma         = 1,
#                   1, 1, 0.0304861, 0.95948, 0.210421,
#                   0.264478, 0.214652, 0.221376
